# %%
import os
import pandas as pd
import shutil
from sklearn.model_selection import train_test_split
import glob

# ============ CONFIG ============
base_dir = '/tf/keras_neural_network/Mis_Tests/plant-pathology-2020-fgvc7/images'     # carpeta donde están las imágenes originales
csv_path = '/tf/keras_neural_network/Mis_Tests/plant-pathology-2020-fgvc7/train.csv' # CSV con image_id (sin extensión) + one-hot cols
extensions_to_try = [".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"]
seed = 42
train_frac = 0.6
test_frac = 0.3
val_frac = 0.1
# ================================

# cargar df
df = pd.read_csv(csv_path)

# columnas de clase (todo excepto image_id)
class_columns = [c for c in df.columns if c != "image_id"]

# function: obtener nombre de clase (primera columna con valor==1)
def get_class_name(row):
    # si los valores no son 0/1 exactos, consideramos >0.5 como positivo
    for col in class_columns:
        try:
            if float(row[col]) == 1 or float(row[col]) > 0.5:
                return col
        except Exception:
            continue
    return None

df["class_name"] = df.apply(get_class_name, axis=1)

# comprobar filas sin clase
no_class = df[df["class_name"].isnull()]
if len(no_class) > 0:
    print(f"[ERROR] {len(no_class)} imágenes sin clase asignada. Ejemplos:")
    print(no_class.head())
    raise SystemExit("Corrige el CSV antes de continuar.")

# construir filenames (no añadimos extensión todavía)
df["image_id_str"] = df["image_id"].astype(str)

# helper para encontrar el archivo con extensión
def find_image_path(base_dir, image_id):
    # busca coincidencias estrictas image_id + ext
    for ext in extensions_to_try:
        candidate = os.path.join(base_dir, image_id + ext)
        if os.path.exists(candidate):
            return candidate
    # si no está, intenta buscar con glob (por si hay sufijos/leading zeros etc)
    pattern = os.path.join(base_dir, image_id + ".*")
    matches = glob.glob(pattern)
    if matches:
        # devuelve el primero que encuentre
        return matches[0]
    return None

# agregar columna con ruta encontrada (pero no fallar aún)
df["file_path"] = df["image_id_str"].apply(lambda iid: find_image_path(base_dir, iid))
missing_files = df[df["file_path"].isnull()]
if len(missing_files) > 0:
    print(f"[WARN] {len(missing_files)} imágenes no encontradas en {base_dir}. Ejemplos:")
    print(missing_files.head())
    # decidimos continuar pero no mover esas entradas
    df = df[~df["file_path"].isnull()].reset_index(drop=True)

# preparar etiquetas para stratify
labels = df["class_name"].values

# comprobar tamaños por clase
class_counts = df["class_name"].value_counts()
min_count = class_counts.min()
print("Recuento por clase (ejemplo):")
print(class_counts.head())

use_stratify = True
if min_count < 2:
    use_stratify = False
    print("[WARN] Al menos una clase tiene <2 muestras. No se podrá hacer 'stratify' correctamente. Se usará partición aleatoria sin estratificar.")

# Primero: train vs temp (train_frac vs 1-train_frac)
if use_stratify:
    train_df, temp_df = train_test_split(df, train_size=train_frac, stratify=labels, random_state=seed, shuffle=True)
else:
    train_df, temp_df = train_test_split(df, train_size=train_frac, random_state=seed, shuffle=True)

# Ahora dividir temp en test y val con proporción relativa
# test_frac_relative = test_frac / (test_frac + val_frac) = 0.3 / 0.4 = 0.75
temp_total = test_frac + val_frac
if temp_total <= 0:
    raise ValueError("test_frac + val_frac debe ser > 0")

test_relative = test_frac / temp_total

if use_stratify:
    test_df, val_df = train_test_split(temp_df, train_size=test_relative, stratify=temp_df["class_name"].values, random_state=seed, shuffle=True)
else:
    test_df, val_df = train_test_split(temp_df, train_size=test_relative, random_state=seed, shuffle=True)

print(f"Split sizes -> train: {len(train_df)}, test: {len(test_df)}, val: {len(val_df)}")

# función para mover archivos a la estructura dataset/{split}/{class}/file
def move_to_split(df_subset, split_name):
    for _, row in df_subset.iterrows():
        src = row["file_path"]
        cls = row["class_name"]
        fname = os.path.basename(src)
        dest_dir = os.path.join(base_dir, split_name, cls)  # carpeta final dentro de la carpeta original
        os.makedirs(dest_dir, exist_ok=True)
        dest = os.path.join(dest_dir, fname)
        try:
            shutil.move(src, dest)
        except Exception as e:
            print(f"[ERROR] al mover {src} → {dest}: {e}")

# mover
move_to_split(train_df, "train")
move_to_split(test_df, "test")
move_to_split(val_df, "val")

print("✅ Movimiento completado.")
# imprimir resumen por split y clase
from collections import Counter
for split_name, d in [("train", train_df), ("test", test_df), ("val", val_df)]:
    c = Counter(d["class_name"].values)
    print(f"--- {split_name} --- total {len(d)}")
    for k, v in c.items():
        print(f"  {k}: {v}")
# Out:
# Recuento por clase (ejemplo):
# class_name
# rust                 622
# scab                 592
# healthy              516
# multiple_diseases     91
# Name: count, dtype: int64
# Split sizes -> train: 1092, test: 546, val: 183
# ✅ Movimiento completado.
# --- train --- total 1092
#   scab: 355
#   rust: 373
#   healthy: 309
#   multiple_diseases: 55
# --- test --- total 546
#   scab: 178
#   rust: 186
#   healthy: 155
#   multiple_diseases: 27
# --- val --- total 183
#   scab: 59
#   healthy: 52
#   rust: 63
#   multiple_diseases: 9

# %%
from PIL import Image
import os
import numpy as np

path = base_dir
folder = ['/train','/test','/val']
subfolder = ['/healthy','/multiple_diseases', '/rust', '/scab']

def resize_with_color_reduction(image_path, target_size=(384, 256), bits_per_channel=6):
    """Resize image and reduce color depth while preserving color information"""
    for item in os.listdir(image_path):
        full_path = os.path.join(image_path, item)
        if os.path.isfile(full_path) and item.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
            try:
                with Image.open(full_path) as im:
                    # Resize to target size (width, height)
                    imResize = im.resize(target_size, Image.Resampling.LANCZOS)
                    
                    # Reduce color depth
                    if bits_per_channel < 8:
                        factor = 256 // (2 ** bits_per_channel)
                        imReduced = imResize.point(lambda x: (x // factor) * factor)
                    else:
                        imReduced = imResize
                    
                    # Save with optimization
                    f, e = os.path.splitext(full_path)
                    imReduced.save(f + '.jpg', 'JPEG', quality=85, optimize=True)
                    
            except Exception as e:
                print(f"Error processing {item}: {e}")

# Process all folders
for i in folder:
    for j in subfolder:
        current_path = path + i + j
        if os.path.exists(current_path):
            resize_with_color_reduction(current_path, target_size=(384, 256), bits_per_channel=6)
        else:
            print(f"Path does not exist: {current_path}")
# Out:
# Processed: Train_3.jpg -> 6 bits/channel
# Processed: Train_281.jpg -> 6 bits/channel
# Processed: Train_125.jpg -> 6 bits/channel
# Processed: Train_1486.jpg -> 6 bits/channel
# Processed: Train_520.jpg -> 6 bits/channel
# Processed: Train_362.jpg -> 6 bits/channel
# Processed: Train_548.jpg -> 6 bits/channel
# Processed: Train_606.jpg -> 6 bits/channel
# Processed: Train_279.jpg -> 6 bits/channel
# Processed: Train_1162.jpg -> 6 bits/channel
# Processed: Train_347.jpg -> 6 bits/channel
# Processed: Train_378.jpg -> 6 bits/channel
# Processed: Train_1316.jpg -> 6 bits/channel
# Processed: Train_1641.jpg -> 6 bits/channel
# Processed: Train_588.jpg -> 6 bits/channel
# Processed: Train_294.jpg -> 6 bits/channel
# Processed: Train_108.jpg -> 6 bits/channel
# Processed: Train_1177.jpg -> 6 bits/channel
# Processed: Train_518.jpg -> 6 bits/channel
# Processed: Train_641.jpg -> 6 bits/channel
# Processed: Train_1082.jpg -> 6 bits/channel
# Processed: Train_615.jpg -> 6 bits/channel
# Processed: Train_1716.jpg -> 6 bits/channel
# Processed: Train_577.jpg -> 6 bits/channel
# Processed: Train_1107.jpg -> 6 bits/channel
# Processed: Train_1337.jpg -> 6 bits/channel
# Processed: Train_197.jpg -> 6 bits/channel
# Processed: Train_1266.jpg -> 6 bits/channel
# Processed: Train_1218.jpg -> 6 bits/channel
# Processed: Train_354.jpg -> 6 bits/channel
# Processed: Train_903.jpg -> 6 bits/channel
# Processed: Train_114.jpg -> 6 bits/channel
# Processed: Train_1406.jpg -> 6 bits/channel
# Processed: Train_151.jpg -> 6 bits/channel
# Processed: Train_860.jpg -> 6 bits/channel
# Processed: Train_1021.jpg -> 6 bits/channel
# Processed: Train_549.jpg -> 6 bits/channel
# Processed: Train_827.jpg -> 6 bits/channel
# Processed: Train_1145.jpg -> 6 bits/channel
# Processed: Train_1239.jpg -> 6 bits/channel
# Processed: Train_1240.jpg -> 6 bits/channel
# Processed: Train_895.jpg -> 6 bits/channel
# Processed: Train_1339.jpg -> 6 bits/channel
# Processed: Train_741.jpg -> 6 bits/channel
# Processed: Train_649.jpg -> 6 bits/channel
# Processed: Train_1132.jpg -> 6 bits/channel
# Processed: Train_126.jpg -> 6 bits/channel
# Processed: Train_60.jpg -> 6 bits/channel
# Processed: Train_134.jpg -> 6 bits/channel
# Processed: Train_607.jpg -> 6 bits/channel
# Processed: Train_1484.jpg -> 6 bits/channel
# Processed: Train_521.jpg -> 6 bits/channel
# Processed: Train_1699.jpg -> 6 bits/channel
# Processed: Train_18.jpg -> 6 bits/channel
# Processed: Train_1819.jpg -> 6 bits/channel
# Processed: Train_93.jpg -> 6 bits/channel
# Processed: Train_481.jpg -> 6 bits/channel
# Processed: Train_1100.jpg -> 6 bits/channel
# Processed: Train_368.jpg -> 6 bits/channel
# Processed: Train_418.jpg -> 6 bits/channel
# Processed: Train_1690.jpg -> 6 bits/channel
# Processed: Train_1258.jpg -> 6 bits/channel
# Processed: Train_888.jpg -> 6 bits/channel
# Processed: Train_127.jpg -> 6 bits/channel
# Processed: Train_733.jpg -> 6 bits/channel
# Processed: Train_445.jpg -> 6 bits/channel
# Processed: Train_1620.jpg -> 6 bits/channel
# Processed: Train_1010.jpg -> 6 bits/channel
# Processed: Train_530.jpg -> 6 bits/channel
# Processed: Train_1459.jpg -> 6 bits/channel
# Processed: Train_869.jpg -> 6 bits/channel
# Processed: Train_1031.jpg -> 6 bits/channel
# Processed: Train_898.jpg -> 6 bits/channel
# Processed: Train_1453.jpg -> 6 bits/channel
# Processed: Train_654.jpg -> 6 bits/channel
# Processed: Train_1475.jpg -> 6 bits/channel
# Processed: Train_709.jpg -> 6 bits/channel
# Processed: Train_489.jpg -> 6 bits/channel
# Processed: Train_147.jpg -> 6 bits/channel
# Processed: Train_254.jpg -> 6 bits/channel
# Processed: Train_64.jpg -> 6 bits/channel
# Processed: Train_1670.jpg -> 6 bits/channel
# Processed: Train_1535.jpg -> 6 bits/channel
# Processed: Train_59.jpg -> 6 bits/channel
# Processed: Train_218.jpg -> 6 bits/channel
# Processed: Train_1378.jpg -> 6 bits/channel
# Processed: Train_53.jpg -> 6 bits/channel
# Processed: Train_791.jpg -> 6 bits/channel
# Processed: Train_679.jpg -> 6 bits/channel
# Processed: Train_1219.jpg -> 6 bits/channel
# Processed: Train_393.jpg -> 6 bits/channel
# Processed: Train_1684.jpg -> 6 bits/channel
# Processed: Train_1613.jpg -> 6 bits/channel
# Processed: Train_1130.jpg -> 6 bits/channel
# Processed: Train_765.jpg -> 6 bits/channel
# Processed: Train_308.jpg -> 6 bits/channel
# Processed: Train_1356.jpg -> 6 bits/channel
# Processed: Train_1097.jpg -> 6 bits/channel
# Processed: Train_648.jpg -> 6 bits/channel
# Processed: Train_1812.jpg -> 6 bits/channel
# Processed: Train_995.jpg -> 6 bits/channel
# Processed: Train_1576.jpg -> 6 bits/channel
# Processed: Train_107.jpg -> 6 bits/channel
# Processed: Train_1069.jpg -> 6 bits/channel
# Processed: Train_652.jpg -> 6 bits/channel
# Processed: Train_613.jpg -> 6 bits/channel
# Processed: Train_1617.jpg -> 6 bits/channel
# Processed: Train_488.jpg -> 6 bits/channel
# Processed: Train_1583.jpg -> 6 bits/channel
# Processed: Train_1496.jpg -> 6 bits/channel
# Processed: Train_1121.jpg -> 6 bits/channel
# Processed: Train_229.jpg -> 6 bits/channel
# Processed: Train_1242.jpg -> 6 bits/channel
# Processed: Train_1307.jpg -> 6 bits/channel
# Processed: Train_1375.jpg -> 6 bits/channel
# Processed: Train_1228.jpg -> 6 bits/channel
# Processed: Train_449.jpg -> 6 bits/channel
# Processed: Train_724.jpg -> 6 bits/channel
# Processed: Train_697.jpg -> 6 bits/channel
# Processed: Train_1320.jpg -> 6 bits/channel
# Processed: Train_1373.jpg -> 6 bits/channel
# Processed: Train_1353.jpg -> 6 bits/channel
# Processed: Train_525.jpg -> 6 bits/channel
# Processed: Train_1560.jpg -> 6 bits/channel
# Processed: Train_1398.jpg -> 6 bits/channel
# Processed: Train_556.jpg -> 6 bits/channel
# Processed: Train_1584.jpg -> 6 bits/channel
# Processed: Train_1705.jpg -> 6 bits/channel
# Processed: Train_574.jpg -> 6 bits/channel
# Processed: Train_470.jpg -> 6 bits/channel
# Processed: Train_1410.jpg -> 6 bits/channel
# Processed: Train_1642.jpg -> 6 bits/channel
# Processed: Train_339.jpg -> 6 bits/channel
# Processed: Train_1732.jpg -> 6 bits/channel
# Processed: Train_1506.jpg -> 6 bits/channel
# Processed: Train_1313.jpg -> 6 bits/channel
# Processed: Train_1072.jpg -> 6 bits/channel
# Processed: Train_1742.jpg -> 6 bits/channel
# Processed: Train_265.jpg -> 6 bits/channel
# Processed: Train_236.jpg -> 6 bits/channel
# Processed: Train_312.jpg -> 6 bits/channel
# Processed: Train_1183.jpg -> 6 bits/channel
# Processed: Train_258.jpg -> 6 bits/channel
# Processed: Train_954.jpg -> 6 bits/channel
# Processed: Train_1703.jpg -> 6 bits/channel
# Processed: Train_156.jpg -> 6 bits/channel
# Processed: Train_1017.jpg -> 6 bits/channel
# Processed: Train_680.jpg -> 6 bits/channel
# Processed: Train_1739.jpg -> 6 bits/channel
# Processed: Train_729.jpg -> 6 bits/channel
# Processed: Train_526.jpg -> 6 bits/channel
# Processed: Train_1607.jpg -> 6 bits/channel
# Processed: Train_139.jpg -> 6 bits/channel
# Processed: Train_727.jpg -> 6 bits/channel
# Processed: Train_1718.jpg -> 6 bits/channel
# Processed: Train_611.jpg -> 6 bits/channel
# Processed: Train_1256.jpg -> 6 bits/channel
# Processed: Train_1707.jpg -> 6 bits/channel
# Processed: Train_1454.jpg -> 6 bits/channel
# Processed: Train_959.jpg -> 6 bits/channel
# Processed: Train_26.jpg -> 6 bits/channel
# Processed: Train_1765.jpg -> 6 bits/channel
# Processed: Train_353.jpg -> 6 bits/channel
# Processed: Train_1205.jpg -> 6 bits/channel
# Processed: Train_1748.jpg -> 6 bits/channel
# Processed: Train_335.jpg -> 6 bits/channel
# Processed: Train_66.jpg -> 6 bits/channel
# Processed: Train_767.jpg -> 6 bits/channel
# Processed: Train_435.jpg -> 6 bits/channel
# Processed: Train_359.jpg -> 6 bits/channel
# Processed: Train_593.jpg -> 6 bits/channel
# Processed: Train_685.jpg -> 6 bits/channel
# Processed: Train_45.jpg -> 6 bits/channel
# Processed: Train_495.jpg -> 6 bits/channel
# Processed: Train_864.jpg -> 6 bits/channel
# Processed: Train_1640.jpg -> 6 bits/channel
# Processed: Train_653.jpg -> 6 bits/channel
# Processed: Train_974.jpg -> 6 bits/channel
# Processed: Train_1655.jpg -> 6 bits/channel
# Processed: Train_61.jpg -> 6 bits/channel
# Processed: Train_1540.jpg -> 6 bits/channel
# Processed: Train_1730.jpg -> 6 bits/channel
# Processed: Train_1352.jpg -> 6 bits/channel
# Processed: Train_832.jpg -> 6 bits/channel
# Processed: Train_1135.jpg -> 6 bits/channel
# Processed: Train_1399.jpg -> 6 bits/channel
# Processed: Train_1523.jpg -> 6 bits/channel
# Processed: Train_825.jpg -> 6 bits/channel
# Processed: Train_1556.jpg -> 6 bits/channel
# Processed: Train_1612.jpg -> 6 bits/channel
# Processed: Train_304.jpg -> 6 bits/channel
# Processed: Train_851.jpg -> 6 bits/channel
# Processed: Train_6.jpg -> 6 bits/channel
# Processed: Train_1759.jpg -> 6 bits/channel
# Processed: Train_1751.jpg -> 6 bits/channel
# Processed: Train_1597.jpg -> 6 bits/channel
# Processed: Train_54.jpg -> 6 bits/channel
# Processed: Train_997.jpg -> 6 bits/channel
# Processed: Train_143.jpg -> 6 bits/channel
# Processed: Train_427.jpg -> 6 bits/channel
# Processed: Train_1558.jpg -> 6 bits/channel
# Processed: Train_290.jpg -> 6 bits/channel
# Processed: Train_558.jpg -> 6 bits/channel
# Processed: Train_1272.jpg -> 6 bits/channel
# Processed: Train_1538.jpg -> 6 bits/channel
# Processed: Train_1427.jpg -> 6 bits/channel
# Processed: Train_918.jpg -> 6 bits/channel
# Processed: Train_260.jpg -> 6 bits/channel
# Processed: Train_1368.jpg -> 6 bits/channel
# Processed: Train_1250.jpg -> 6 bits/channel
# Processed: Train_541.jpg -> 6 bits/channel
# Processed: Train_1588.jpg -> 6 bits/channel
# Processed: Train_1035.jpg -> 6 bits/channel
# Processed: Train_5.jpg -> 6 bits/channel
# Processed: Train_1.jpg -> 6 bits/channel
# Processed: Train_1544.jpg -> 6 bits/channel
# Processed: Train_660.jpg -> 6 bits/channel
# Processed: Train_1304.jpg -> 6 bits/channel
# Processed: Train_1384.jpg -> 6 bits/channel
# Processed: Train_1766.jpg -> 6 bits/channel
# Processed: Train_563.jpg -> 6 bits/channel
# Processed: Train_1391.jpg -> 6 bits/channel
# Processed: Train_1820.jpg -> 6 bits/channel
# Processed: Train_689.jpg -> 6 bits/channel
# Processed: Train_491.jpg -> 6 bits/channel
# Processed: Train_1805.jpg -> 6 bits/channel
# Processed: Train_1420.jpg -> 6 bits/channel
# Processed: Train_57.jpg -> 6 bits/channel
# Processed: Train_73.jpg -> 6 bits/channel
# Processed: Train_1775.jpg -> 6 bits/channel
# Processed: Train_955.jpg -> 6 bits/channel
# Processed: Train_461.jpg -> 6 bits/channel
# Processed: Train_145.jpg -> 6 bits/channel
# Processed: Train_870.jpg -> 6 bits/channel
# Processed: Train_413.jpg -> 6 bits/channel
# Processed: Train_658.jpg -> 6 bits/channel
# Processed: Train_874.jpg -> 6 bits/channel
# Processed: Train_173.jpg -> 6 bits/channel
# Processed: Train_1791.jpg -> 6 bits/channel
# Processed: Train_419.jpg -> 6 bits/channel
# Processed: Train_297.jpg -> 6 bits/channel
# Processed: Train_1528.jpg -> 6 bits/channel
# Processed: Train_1450.jpg -> 6 bits/channel
# Processed: Train_219.jpg -> 6 bits/channel
# Processed: Train_639.jpg -> 6 bits/channel
# Processed: Train_1651.jpg -> 6 bits/channel
# Processed: Train_542.jpg -> 6 bits/channel
# Processed: Train_683.jpg -> 6 bits/channel
# Processed: Train_51.jpg -> 6 bits/channel
# Processed: Train_1778.jpg -> 6 bits/channel
# Processed: Train_486.jpg -> 6 bits/channel
# Processed: Train_738.jpg -> 6 bits/channel
# Processed: Train_475.jpg -> 6 bits/channel
# Processed: Train_668.jpg -> 6 bits/channel
# Processed: Train_1163.jpg -> 6 bits/channel
# Processed: Train_1405.jpg -> 6 bits/channel
# Processed: Train_753.jpg -> 6 bits/channel
# Processed: Train_1708.jpg -> 6 bits/channel
# Processed: Train_78.jpg -> 6 bits/channel
# Processed: Train_862.jpg -> 6 bits/channel
# Processed: Train_343.jpg -> 6 bits/channel
# Processed: Train_345.jpg -> 6 bits/channel
# Processed: Train_1638.jpg -> 6 bits/channel
# Processed: Train_629.jpg -> 6 bits/channel
# Processed: Train_1599.jpg -> 6 bits/channel
# Processed: Train_721.jpg -> 6 bits/channel
# Processed: Train_79.jpg -> 6 bits/channel
# Processed: Train_1702.jpg -> 6 bits/channel
# Processed: Train_1479.jpg -> 6 bits/channel
# Processed: Train_1149.jpg -> 6 bits/channel
# Processed: Train_1601.jpg -> 6 bits/channel
# Processed: Train_790.jpg -> 6 bits/channel
# Processed: Train_1694.jpg -> 6 bits/channel
# Processed: Train_1283.jpg -> 6 bits/channel
# Processed: Train_1148.jpg -> 6 bits/channel
# Processed: Train_253.jpg -> 6 bits/channel
# Processed: Train_631.jpg -> 6 bits/channel
# Processed: Train_942.jpg -> 6 bits/channel
# Processed: Train_1011.jpg -> 6 bits/channel
# Processed: Train_331.jpg -> 6 bits/channel
# Processed: Train_1418.jpg -> 6 bits/channel
# Processed: Train_1478.jpg -> 6 bits/channel
# Processed: Train_842.jpg -> 6 bits/channel
# Processed: Train_323.jpg -> 6 bits/channel
# Processed: Train_663.jpg -> 6 bits/channel
# Processed: Train_273.jpg -> 6 bits/channel
# Processed: Train_433.jpg -> 6 bits/channel
# Processed: Train_153.jpg -> 6 bits/channel
# Processed: Train_910.jpg -> 6 bits/channel
# Processed: Train_1169.jpg -> 6 bits/channel
# Processed: Train_1146.jpg -> 6 bits/channel
# Processed: Train_1282.jpg -> 6 bits/channel
# Processed: Train_1344.jpg -> 6 bits/channel
# Processed: Train_717.jpg -> 6 bits/channel
# Processed: Train_855.jpg -> 6 bits/channel
# Processed: Train_301.jpg -> 6 bits/channel
# Processed: Train_235.jpg -> 6 bits/channel
# Processed: Train_1811.jpg -> 6 bits/channel
# Processed: Train_178.jpg -> 6 bits/channel
# Processed: Train_232.jpg -> 6 bits/channel
# Processed: Train_1762.jpg -> 6 bits/channel
# Processed: Train_1200.jpg -> 6 bits/channel
# Processed: Train_1276.jpg -> 6 bits/channel
# Processed: Train_1309.jpg -> 6 bits/channel
# Processed: Train_1773.jpg -> 6 bits/channel
# Processed: Train_1086.jpg -> 6 bits/channel
# Processed: Train_361.jpg -> 6 bits/channel
# Processed: Train_976.jpg -> 6 bits/channel
# Processed: Train_1295.jpg -> 6 bits/channel
# Processed: Train_893.jpg -> 6 bits/channel
# Processed: Train_555.jpg -> 6 bits/channel
# Processed: Train_1230.jpg -> 6 bits/channel
# Processed: Train_818.jpg -> 6 bits/channel
# Processed: Train_240.jpg -> 6 bits/channel
# Processed: Train_690.jpg -> 6 bits/channel
# Processed: Train_751.jpg -> 6 bits/channel
# Processed: Train_990.jpg -> 6 bits/channel
# Processed: Train_1619.jpg -> 6 bits/channel
# Processed: Train_161.jpg -> 6 bits/channel
# Processed: Train_522.jpg -> 6 bits/channel
# Processed: Train_1631.jpg -> 6 bits/channel
# Processed: Train_1038.jpg -> 6 bits/channel
# Processed: Train_1027.jpg -> 6 bits/channel
# Processed: Train_1448.jpg -> 6 bits/channel
# Processed: Train_951.jpg -> 6 bits/channel
# Processed: Train_965.jpg -> 6 bits/channel
# Processed: Train_887.jpg -> 6 bits/channel
# Processed: Train_731.jpg -> 6 bits/channel
# Processed: Train_1285.jpg -> 6 bits/channel
# Processed: Train_1144.jpg -> 6 bits/channel
# Processed: Train_85.jpg -> 6 bits/channel
# Processed: Train_797.jpg -> 6 bits/channel
# Processed: Train_212.jpg -> 6 bits/channel
# Processed: Train_1292.jpg -> 6 bits/channel
# Processed: Train_497.jpg -> 6 bits/channel
# Processed: Train_1704.jpg -> 6 bits/channel
# Processed: Train_742.jpg -> 6 bits/channel
# Processed: Train_1531.jpg -> 6 bits/channel
# Processed: Train_1122.jpg -> 6 bits/channel
# Processed: Train_584.jpg -> 6 bits/channel
# Processed: Train_150.jpg -> 6 bits/channel
# Processed: Train_911.jpg -> 6 bits/channel
# Processed: Train_1390.jpg -> 6 bits/channel
# Processed: Train_560.jpg -> 6 bits/channel
# Processed: Train_528.jpg -> 6 bits/channel
# Processed: Train_638.jpg -> 6 bits/channel
# Processed: Train_1376.jpg -> 6 bits/channel
# Processed: Train_1395.jpg -> 6 bits/channel
# Processed: Train_1646.jpg -> 6 bits/channel
# Processed: Train_1015.jpg -> 6 bits/channel
# Processed: Train_377.jpg -> 6 bits/channel
# Processed: Train_11.jpg -> 6 bits/channel
# Processed: Train_978.jpg -> 6 bits/channel
# Processed: Train_1492.jpg -> 6 bits/channel
# Processed: Train_101.jpg -> 6 bits/channel
# Processed: Train_873.jpg -> 6 bits/channel
# Processed: Train_314.jpg -> 6 bits/channel
# Processed: Train_68.jpg -> 6 bits/channel
# Processed: Train_148.jpg -> 6 bits/channel
# Processed: Train_632.jpg -> 6 bits/channel
# Processed: Train_410.jpg -> 6 bits/channel
# Processed: Train_1779.jpg -> 6 bits/channel
# Processed: Train_936.jpg -> 6 bits/channel
# Processed: Train_171.jpg -> 6 bits/channel
# Processed: Train_1430.jpg -> 6 bits/channel
# Processed: Train_1061.jpg -> 6 bits/channel
# Processed: Train_201.jpg -> 6 bits/channel
# Processed: Train_706.jpg -> 6 bits/channel
# Processed: Train_1003.jpg -> 6 bits/channel
# Processed: Train_455.jpg -> 6 bits/channel
# Processed: Train_1070.jpg -> 6 bits/channel
# Processed: Train_1112.jpg -> 6 bits/channel
# Processed: Train_1028.jpg -> 6 bits/channel
# Processed: Train_1068.jpg -> 6 bits/channel
# Processed: Train_823.jpg -> 6 bits/channel
# Processed: Train_1348.jpg -> 6 bits/channel
# Processed: Train_801.jpg -> 6 bits/channel
# Processed: Train_1521.jpg -> 6 bits/channel
# Processed: Train_130.jpg -> 6 bits/channel
# Processed: Train_589.jpg -> 6 bits/channel
# Processed: Train_276.jpg -> 6 bits/channel
# Processed: Train_704.jpg -> 6 bits/channel
# Processed: Train_538.jpg -> 6 bits/channel
# Processed: Train_1614.jpg -> 6 bits/channel
# Processed: Train_1445.jpg -> 6 bits/channel
# Processed: Train_1034.jpg -> 6 bits/channel
# Processed: Train_591.jpg -> 6 bits/channel
# Processed: Train_319.jpg -> 6 bits/channel
# Processed: Train_332.jpg -> 6 bits/channel
# Processed: Train_1669.jpg -> 6 bits/channel
# Processed: Train_1302.jpg -> 6 bits/channel
# Processed: Train_601.jpg -> 6 bits/channel
# Processed: Train_1009.jpg -> 6 bits/channel
# Processed: Train_796.jpg -> 6 bits/channel
# Processed: Train_213.jpg -> 6 bits/channel
# Processed: Train_1573.jpg -> 6 bits/channel
# Processed: Train_1639.jpg -> 6 bits/channel
# Processed: Train_1088.jpg -> 6 bits/channel
# Processed: Train_1746.jpg -> 6 bits/channel
# Processed: Train_1717.jpg -> 6 bits/channel
# Processed: Train_1768.jpg -> 6 bits/channel
# Processed: Train_292.jpg -> 6 bits/channel
# Processed: Train_1236.jpg -> 6 bits/channel
# Processed: Train_871.jpg -> 6 bits/channel
# Processed: Train_749.jpg -> 6 bits/channel
# Processed: Train_996.jpg -> 6 bits/channel
# Processed: Train_200.jpg -> 6 bits/channel
# Processed: Train_1665.jpg -> 6 bits/channel
# Processed: Train_640.jpg -> 6 bits/channel
# Processed: Train_1085.jpg -> 6 bits/channel
# Processed: Train_477.jpg -> 6 bits/channel
# Processed: Train_1386.jpg -> 6 bits/channel
# Processed: Train_505.jpg -> 6 bits/channel
# Processed: Train_1004.jpg -> 6 bits/channel
# Processed: Train_1787.jpg -> 6 bits/channel
# Processed: Train_770.jpg -> 6 bits/channel
# Processed: Train_109.jpg -> 6 bits/channel
# Processed: Train_1426.jpg -> 6 bits/channel
# Processed: Train_1195.jpg -> 6 bits/channel
# Processed: Train_623.jpg -> 6 bits/channel
# Processed: Train_992.jpg -> 6 bits/channel
# Processed: Train_1524.jpg -> 6 bits/channel
# Processed: Train_462.jpg -> 6 bits/channel
# Processed: Train_881.jpg -> 6 bits/channel
# Processed: Train_1485.jpg -> 6 bits/channel
# Processed: Train_1529.jpg -> 6 bits/channel
# Processed: Train_1008.jpg -> 6 bits/channel
# Processed: Train_981.jpg -> 6 bits/channel
# Processed: Train_394.jpg -> 6 bits/channel
# Processed: Train_1371.jpg -> 6 bits/channel
# Processed: Train_1350.jpg -> 6 bits/channel
# Processed: Train_473.jpg -> 6 bits/channel
# Processed: Train_1062.jpg -> 6 bits/channel
# Processed: Train_1814.jpg -> 6 bits/channel
# Processed: Train_1081.jpg -> 6 bits/channel
# Processed: Train_856.jpg -> 6 bits/channel
# Processed: Train_170.jpg -> 6 bits/channel
# Processed: Train_597.jpg -> 6 bits/channel
# Processed: Train_1626.jpg -> 6 bits/channel
# Processed: Train_1393.jpg -> 6 bits/channel
# Processed: Train_144.jpg -> 6 bits/channel
# Processed: Train_626.jpg -> 6 bits/channel
# Processed: Train_465.jpg -> 6 bits/channel
# Processed: Train_537.jpg -> 6 bits/channel
# Processed: Train_138.jpg -> 6 bits/channel
# Processed: Train_1404.jpg -> 6 bits/channel
# Processed: Train_1317.jpg -> 6 bits/channel
# Processed: Train_824.jpg -> 6 bits/channel
# Processed: Train_1168.jpg -> 6 bits/channel
# Processed: Train_599.jpg -> 6 bits/channel
# Processed: Train_38.jpg -> 6 bits/channel
# Processed: Train_515.jpg -> 6 bits/channel
# Processed: Train_1512.jpg -> 6 bits/channel
# Processed: Train_578.jpg -> 6 bits/channel
# Processed: Train_1151.jpg -> 6 bits/channel
# Processed: Train_947.jpg -> 6 bits/channel
# Processed: Train_1226.jpg -> 6 bits/channel
# Processed: Train_1118.jpg -> 6 bits/channel
# Processed: Train_84.jpg -> 6 bits/channel
# Processed: Train_234.jpg -> 6 bits/channel
# Processed: Train_214.jpg -> 6 bits/channel
# Processed: Train_1435.jpg -> 6 bits/channel
# Processed: Train_596.jpg -> 6 bits/channel
# Processed: Train_1610.jpg -> 6 bits/channel
# Processed: Train_1201.jpg -> 6 bits/channel
# Processed: Train_750.jpg -> 6 bits/channel
# Processed: Train_1446.jpg -> 6 bits/channel
# Processed: Train_485.jpg -> 6 bits/channel
# Processed: Train_1143.jpg -> 6 bits/channel
# Processed: Train_443.jpg -> 6 bits/channel
# Processed: Train_1052.jpg -> 6 bits/channel
# Processed: Train_1323.jpg -> 6 bits/channel
# Processed: Train_760.jpg -> 6 bits/channel
# Processed: Train_494.jpg -> 6 bits/channel
# Processed: Train_441.jpg -> 6 bits/channel
# Processed: Train_1644.jpg -> 6 bits/channel
# Processed: Train_1341.jpg -> 6 bits/channel
# Processed: Train_836.jpg -> 6 bits/channel
# Processed: Train_1065.jpg -> 6 bits/channel
# Processed: Train_432.jpg -> 6 bits/channel
# Processed: Train_99.jpg -> 6 bits/channel
# Processed: Train_464.jpg -> 6 bits/channel
# Processed: Train_1089.jpg -> 6 bits/channel
# Processed: Train_958.jpg -> 6 bits/channel
# Processed: Train_293.jpg -> 6 bits/channel
# Processed: Train_1380.jpg -> 6 bits/channel
# Processed: Train_1635.jpg -> 6 bits/channel
# Processed: Train_1160.jpg -> 6 bits/channel
# Processed: Train_1262.jpg -> 6 bits/channel
# Processed: Train_1138.jpg -> 6 bits/channel
# Processed: Train_140.jpg -> 6 bits/channel
# Processed: Train_585.jpg -> 6 bits/channel
# Processed: Train_1330.jpg -> 6 bits/channel
# Processed: Train_545.jpg -> 6 bits/channel
# Processed: Train_1550.jpg -> 6 bits/channel
# Processed: Train_504.jpg -> 6 bits/channel
# Processed: Train_1102.jpg -> 6 bits/channel
# Processed: Train_1592.jpg -> 6 bits/channel
# Processed: Train_288.jpg -> 6 bits/channel
# Processed: Train_1108.jpg -> 6 bits/channel
# Processed: Train_1500.jpg -> 6 bits/channel
# Processed: Train_25.jpg -> 6 bits/channel
# Processed: Train_651.jpg -> 6 bits/channel
# Processed: Train_408.jpg -> 6 bits/channel
# Processed: Train_682.jpg -> 6 bits/channel
# Processed: Train_1691.jpg -> 6 bits/channel
# Processed: Train_436.jpg -> 6 bits/channel
# Processed: Train_1263.jpg -> 6 bits/channel
# Processed: Train_1245.jpg -> 6 bits/channel
# Processed: Train_1813.jpg -> 6 bits/channel
# Processed: Train_1477.jpg -> 6 bits/channel
# Processed: Train_500.jpg -> 6 bits/channel
# Processed: Train_1101.jpg -> 6 bits/channel
# Processed: Train_1322.jpg -> 6 bits/channel
# Processed: Train_1180.jpg -> 6 bits/channel
# Processed: Train_858.jpg -> 6 bits/channel
# Processed: Train_1555.jpg -> 6 bits/channel
# Processed: Train_396.jpg -> 6 bits/channel
# Processed: Train_970.jpg -> 6 bits/channel
# Processed: Train_248.jpg -> 6 bits/channel
# Processed: Train_77.jpg -> 6 bits/channel
# Processed: Train_1223.jpg -> 6 bits/channel
# Processed: Train_1429.jpg -> 6 bits/channel
# Processed: Train_88.jpg -> 6 bits/channel
# Processed: Train_74.jpg -> 6 bits/channel
# Processed: Train_1662.jpg -> 6 bits/channel
# Processed: Train_216.jpg -> 6 bits/channel
# Processed: Train_1087.jpg -> 6 bits/channel
# Processed: Train_1424.jpg -> 6 bits/channel
# Processed: Train_583.jpg -> 6 bits/channel
# Processed: Train_1297.jpg -> 6 bits/channel
# Processed: Train_1571.jpg -> 6 bits/channel
# Processed: Train_564.jpg -> 6 bits/channel
# Processed: Train_1579.jpg -> 6 bits/channel
# Processed: Train_822.jpg -> 6 bits/channel
# Processed: Train_646.jpg -> 6 bits/channel
# Processed: Train_956.jpg -> 6 bits/channel
# Processed: Train_1589.jpg -> 6 bits/channel
# Processed: Train_513.jpg -> 6 bits/channel
# Processed: Train_199.jpg -> 6 bits/channel
# Processed: Train_1487.jpg -> 6 bits/channel
# Processed: Train_162.jpg -> 6 bits/channel
# Processed: Train_968.jpg -> 6 bits/channel
# Processed: Train_688.jpg -> 6 bits/channel
# Processed: Train_657.jpg -> 6 bits/channel
# Processed: Train_1044.jpg -> 6 bits/channel
# Processed: Train_1693.jpg -> 6 bits/channel
# Processed: Train_27.jpg -> 6 bits/channel
# Processed: Train_664.jpg -> 6 bits/channel
# Processed: Train_1774.jpg -> 6 bits/channel
# Processed: Train_605.jpg -> 6 bits/channel
# Processed: Train_736.jpg -> 6 bits/channel
# Processed: Train_766.jpg -> 6 bits/channel
# Processed: Train_72.jpg -> 6 bits/channel
# Processed: Train_35.jpg -> 6 bits/channel
# Processed: Train_165.jpg -> 6 bits/channel
# Processed: Train_1815.jpg -> 6 bits/channel
# Processed: Train_1618.jpg -> 6 bits/channel
# Processed: Train_307.jpg -> 6 bits/channel
# Processed: Train_1792.jpg -> 6 bits/channel
# Processed: Train_1678.jpg -> 6 bits/channel
# Processed: Train_1671.jpg -> 6 bits/channel
# Processed: Train_1286.jpg -> 6 bits/channel
# Processed: Train_1623.jpg -> 6 bits/channel
# Processed: Train_89.jpg -> 6 bits/channel
# Processed: Train_1798.jpg -> 6 bits/channel
# Processed: Train_483.jpg -> 6 bits/channel
# Processed: Train_524.jpg -> 6 bits/channel
# Processed: Train_458.jpg -> 6 bits/channel
# Processed: Train_1557.jpg -> 6 bits/channel
# Processed: Train_311.jpg -> 6 bits/channel
# Processed: Train_1152.jpg -> 6 bits/channel
# Processed: Train_880.jpg -> 6 bits/channel
# Processed: Train_1434.jpg -> 6 bits/channel
# Processed: Train_424.jpg -> 6 bits/channel
# Processed: Train_854.jpg -> 6 bits/channel
# Processed: Train_1193.jpg -> 6 bits/channel
# Processed: Train_1807.jpg -> 6 bits/channel
# Processed: Train_1431.jpg -> 6 bits/channel
# Processed: Train_1222.jpg -> 6 bits/channel
# Processed: Train_886.jpg -> 6 bits/channel
# Processed: Train_1753.jpg -> 6 bits/channel
# Processed: Train_859.jpg -> 6 bits/channel
# Processed: Train_1182.jpg -> 6 bits/channel
# Processed: Train_185.jpg -> 6 bits/channel
# Processed: Train_1553.jpg -> 6 bits/channel
# Processed: Train_1667.jpg -> 6 bits/channel
# Processed: Train_1764.jpg -> 6 bits/channel
# Processed: Train_457.jpg -> 6 bits/channel
# Processed: Train_1187.jpg -> 6 bits/channel
# Processed: Train_1331.jpg -> 6 bits/channel
# Processed: Train_244.jpg -> 6 bits/channel
# Processed: Train_1414.jpg -> 6 bits/channel
# Processed: Train_1530.jpg -> 6 bits/channel
# Processed: Train_1247.jpg -> 6 bits/channel
# Processed: Train_891.jpg -> 6 bits/channel
# Processed: Train_1179.jpg -> 6 bits/channel
# Processed: Train_1063.jpg -> 6 bits/channel
# Processed: Train_48.jpg -> 6 bits/channel
# Processed: Train_699.jpg -> 6 bits/channel
# Processed: Train_268.jpg -> 6 bits/channel
# Processed: Train_96.jpg -> 6 bits/channel
# Processed: Train_1141.jpg -> 6 bits/channel
# Processed: Train_966.jpg -> 6 bits/channel
# Processed: Train_1215.jpg -> 6 bits/channel
# Processed: Train_1023.jpg -> 6 bits/channel
# Processed: Train_309.jpg -> 6 bits/channel
# Processed: Train_517.jpg -> 6 bits/channel
# Processed: Train_1096.jpg -> 6 bits/channel
# Processed: Train_700.jpg -> 6 bits/channel
# Processed: Train_863.jpg -> 6 bits/channel
# Processed: Train_1627.jpg -> 6 bits/channel
# Processed: Train_58.jpg -> 6 bits/channel
# Processed: Train_908.jpg -> 6 bits/channel
# Processed: Train_1210.jpg -> 6 bits/channel
# Processed: Train_1664.jpg -> 6 bits/channel
# Processed: Train_592.jpg -> 6 bits/channel
# Processed: Train_569.jpg -> 6 bits/channel
# Processed: Train_426.jpg -> 6 bits/channel
# Processed: Train_1067.jpg -> 6 bits/channel
# Processed: Train_1319.jpg -> 6 bits/channel
# Processed: Train_1686.jpg -> 6 bits/channel
# Processed: Train_582.jpg -> 6 bits/channel
# Processed: Train_1432.jpg -> 6 bits/channel
# Processed: Train_572.jpg -> 6 bits/channel
# Processed: Train_777.jpg -> 6 bits/channel
# Processed: Train_925.jpg -> 6 bits/channel
# Processed: Train_1637.jpg -> 6 bits/channel
# Processed: Train_1713.jpg -> 6 bits/channel
# Processed: Train_650.jpg -> 6 bits/channel
# Processed: Train_1474.jpg -> 6 bits/channel
# Processed: Train_1698.jpg -> 6 bits/channel
# Processed: Train_906.jpg -> 6 bits/channel
# Processed: Train_1155.jpg -> 6 bits/channel
# Processed: Train_1799.jpg -> 6 bits/channel
# Processed: Train_1688.jpg -> 6 bits/channel
# Processed: Train_1697.jpg -> 6 bits/channel
# Processed: Train_450.jpg -> 6 bits/channel
# Processed: Train_298.jpg -> 6 bits/channel
# Processed: Train_900.jpg -> 6 bits/channel
# Processed: Train_1525.jpg -> 6 bits/channel
# Processed: Train_1099.jpg -> 6 bits/channel
# Processed: Train_712.jpg -> 6 bits/channel
# Processed: Train_609.jpg -> 6 bits/channel
# Processed: Train_37.jpg -> 6 bits/channel
# Processed: Train_1680.jpg -> 6 bits/channel
# Processed: Train_819.jpg -> 6 bits/channel
# Processed: Train_366.jpg -> 6 bits/channel
# Processed: Train_460.jpg -> 6 bits/channel
# Processed: Train_1053.jpg -> 6 bits/channel
# Processed: Train_1796.jpg -> 6 bits/channel
# Processed: Train_277.jpg -> 6 bits/channel
# Processed: Train_177.jpg -> 6 bits/channel
# Processed: Train_1213.jpg -> 6 bits/channel
# Processed: Train_813.jpg -> 6 bits/channel
# Processed: Train_814.jpg -> 6 bits/channel
# Processed: Train_774.jpg -> 6 bits/channel
# Processed: Train_167.jpg -> 6 bits/channel
# Processed: Train_921.jpg -> 6 bits/channel
# Processed: Train_715.jpg -> 6 bits/channel
# Processed: Train_1634.jpg -> 6 bits/channel
# Processed: Train_422.jpg -> 6 bits/channel
# Processed: Train_600.jpg -> 6 bits/channel
# Processed: Train_506.jpg -> 6 bits/channel
# Processed: Train_868.jpg -> 6 bits/channel
# Processed: Train_447.jpg -> 6 bits/channel
# Processed: Train_181.jpg -> 6 bits/channel
# Processed: Train_675.jpg -> 6 bits/channel
# Processed: Train_1630.jpg -> 6 bits/channel
# Processed: Train_1041.jpg -> 6 bits/channel
# Processed: Train_222.jpg -> 6 bits/channel
# Processed: Train_848.jpg -> 6 bits/channel
# Processed: Train_1502.jpg -> 6 bits/channel
# Processed: Train_809.jpg -> 6 bits/channel
# Processed: Train_705.jpg -> 6 bits/channel
# Processed: Train_1721.jpg -> 6 bits/channel
# Processed: Train_98.jpg -> 6 bits/channel
# Processed: Train_1314.jpg -> 6 bits/channel
# Processed: Train_1649.jpg -> 6 bits/channel
# Processed: Train_472.jpg -> 6 bits/channel
# Processed: Train_430.jpg -> 6 bits/channel
# Processed: Train_1194.jpg -> 6 bits/channel
# Processed: Train_768.jpg -> 6 bits/channel
# Processed: Train_82.jpg -> 6 bits/channel
# Processed: Train_310.jpg -> 6 bits/channel
# Processed: Train_1208.jpg -> 6 bits/channel
# Processed: Train_1064.jpg -> 6 bits/channel
# Processed: Train_1237.jpg -> 6 bits/channel
# Processed: Train_1741.jpg -> 6 bits/channel
# Processed: Train_1019.jpg -> 6 bits/channel
# Processed: Train_850.jpg -> 6 bits/channel
# Processed: Train_1362.jpg -> 6 bits/channel
# Processed: Train_22.jpg -> 6 bits/channel
# Processed: Train_581.jpg -> 6 bits/channel
# Processed: Train_1534.jpg -> 6 bits/channel
# Processed: Train_988.jpg -> 6 bits/channel
# Processed: Train_1551.jpg -> 6 bits/channel
# Processed: Train_628.jpg -> 6 bits/channel
# Processed: Train_1103.jpg -> 6 bits/channel
# Processed: Train_1483.jpg -> 6 bits/channel
# Processed: Train_1547.jpg -> 6 bits/channel
# Processed: Train_948.jpg -> 6 bits/channel
# Processed: Train_1324.jpg -> 6 bits/channel
# Processed: Train_762.jpg -> 6 bits/channel
# Processed: Train_187.jpg -> 6 bits/channel
# Processed: Train_321.jpg -> 6 bits/channel
# Processed: Train_708.jpg -> 6 bits/channel
# Processed: Train_1482.jpg -> 6 bits/channel
# Processed: Train_341.jpg -> 6 bits/channel
# Processed: Train_112.jpg -> 6 bits/channel
# Processed: Train_939.jpg -> 6 bits/channel
# Processed: Train_1129.jpg -> 6 bits/channel
# Processed: Train_1372.jpg -> 6 bits/channel
# Processed: Train_1419.jpg -> 6 bits/channel
# Processed: Train_826.jpg -> 6 bits/channel
# Processed: Train_672.jpg -> 6 bits/channel
# Processed: Train_1294.jpg -> 6 bits/channel
# Processed: Train_1606.jpg -> 6 bits/channel
# Processed: Train_1084.jpg -> 6 bits/channel
# Processed: Train_952.jpg -> 6 bits/channel
# Processed: Train_1793.jpg -> 6 bits/channel
# Processed: Train_1315.jpg -> 6 bits/channel
# Processed: Train_1733.jpg -> 6 bits/channel
# Processed: Train_274.jpg -> 6 bits/channel
# Processed: Train_759.jpg -> 6 bits/channel
# Processed: Train_1402.jpg -> 6 bits/channel
# Processed: Train_388.jpg -> 6 bits/channel
# Processed: Train_933.jpg -> 6 bits/channel
# Processed: Train_31.jpg -> 6 bits/channel
# Processed: Train_830.jpg -> 6 bits/channel
# Processed: Train_1216.jpg -> 6 bits/channel
# Processed: Train_573.jpg -> 6 bits/channel
# Processed: Train_1056.jpg -> 6 bits/channel
# Processed: Train_732.jpg -> 6 bits/channel
# Processed: Train_1585.jpg -> 6 bits/channel
# Processed: Train_624.jpg -> 6 bits/channel
# Processed: Train_1046.jpg -> 6 bits/channel
# Processed: Train_735.jpg -> 6 bits/channel
# Processed: Train_1248.jpg -> 6 bits/channel
# Processed: Train_701.jpg -> 6 bits/channel
# Processed: Train_479.jpg -> 6 bits/channel
# Processed: Train_1018.jpg -> 6 bits/channel
# Processed: Train_710.jpg -> 6 bits/channel
# Processed: Train_1444.jpg -> 6 bits/channel
# Processed: Train_772.jpg -> 6 bits/channel
# Processed: Train_1243.jpg -> 6 bits/channel
# Processed: Train_193.jpg -> 6 bits/channel
# Processed: Train_734.jpg -> 6 bits/channel
# Processed: Train_195.jpg -> 6 bits/channel
# Processed: Train_811.jpg -> 6 bits/channel
# Processed: Train_239.jpg -> 6 bits/channel
# Processed: Train_1173.jpg -> 6 bits/channel
# Processed: Train_1609.jpg -> 6 bits/channel
# Processed: Train_1628.jpg -> 6 bits/channel
# Processed: Train_844.jpg -> 6 bits/channel
# Processed: Train_1565.jpg -> 6 bits/channel
# Processed: Train_357.jpg -> 6 bits/channel
# Processed: Train_452.jpg -> 6 bits/channel
# Processed: Train_7.jpg -> 6 bits/channel
# Processed: Train_313.jpg -> 6 bits/channel
# Processed: Train_1440.jpg -> 6 bits/channel
# Processed: Train_211.jpg -> 6 bits/channel
# Processed: Train_92.jpg -> 6 bits/channel
# Processed: Train_1301.jpg -> 6 bits/channel
# Processed: Train_1273.jpg -> 6 bits/channel
# Processed: Train_157.jpg -> 6 bits/channel
# Processed: Train_94.jpg -> 6 bits/channel
# Processed: Train_1498.jpg -> 6 bits/channel
# Processed: Train_90.jpg -> 6 bits/channel
# Processed: Train_1257.jpg -> 6 bits/channel
# Processed: Train_480.jpg -> 6 bits/channel
# Processed: Train_365.jpg -> 6 bits/channel
# Processed: Train_1439.jpg -> 6 bits/channel
# Processed: Train_349.jpg -> 6 bits/channel
# Processed: Train_620.jpg -> 6 bits/channel
# Processed: Train_1674.jpg -> 6 bits/channel
# Processed: Train_267.jpg -> 6 bits/channel
# Processed: Train_703.jpg -> 6 bits/channel
# Processed: Train_722.jpg -> 6 bits/channel
# Processed: Train_1229.jpg -> 6 bits/channel
# Processed: Train_1661.jpg -> 6 bits/channel
# Processed: Train_49.jpg -> 6 bits/channel
# Processed: Train_1546.jpg -> 6 bits/channel
# Processed: Train_779.jpg -> 6 bits/channel
# Processed: Train_386.jpg -> 6 bits/channel
# Processed: Train_714.jpg -> 6 bits/channel
# Processed: Train_1153.jpg -> 6 bits/channel
# Processed: Train_656.jpg -> 6 bits/channel
# Processed: Train_1574.jpg -> 6 bits/channel
# Processed: Train_146.jpg -> 6 bits/channel
# Processed: Train_979.jpg -> 6 bits/channel
# Processed: Train_677.jpg -> 6 bits/channel
# Processed: Train_926.jpg -> 6 bits/channel
# Processed: Train_399.jpg -> 6 bits/channel
# Processed: Train_190.jpg -> 6 bits/channel
# Processed: Train_1113.jpg -> 6 bits/channel
# Processed: Train_106.jpg -> 6 bits/channel
# Processed: Train_1351.jpg -> 6 bits/channel
# Processed: Train_669.jpg -> 6 bits/channel
# Processed: Train_782.jpg -> 6 bits/channel
# Processed: Train_1252.jpg -> 6 bits/channel
# Processed: Train_468.jpg -> 6 bits/channel
# Processed: Train_271.jpg -> 6 bits/channel
# Processed: Train_618.jpg -> 6 bits/channel
# Processed: Train_113.jpg -> 6 bits/channel
# Processed: Train_1326.jpg -> 6 bits/channel
# Processed: Train_442.jpg -> 6 bits/channel
# Processed: Train_1363.jpg -> 6 bits/channel
# Processed: Train_1790.jpg -> 6 bits/channel
# Processed: Train_1490.jpg -> 6 bits/channel
# Processed: Train_833.jpg -> 6 bits/channel
# Processed: Train_182.jpg -> 6 bits/channel
# Processed: Train_463.jpg -> 6 bits/channel
# Processed: Train_337.jpg -> 6 bits/channel
# Processed: Train_1308.jpg -> 6 bits/channel
# Processed: Train_788.jpg -> 6 bits/channel
# Processed: Train_883.jpg -> 6 bits/channel
# Processed: Train_1801.jpg -> 6 bits/channel
# Processed: Train_1284.jpg -> 6 bits/channel
# Processed: Train_1756.jpg -> 6 bits/channel
# Processed: Train_493.jpg -> 6 bits/channel
# Processed: Train_840.jpg -> 6 bits/channel
# Processed: Train_1366.jpg -> 6 bits/channel
# Processed: Train_1125.jpg -> 6 bits/channel
# Processed: Train_1611.jpg -> 6 bits/channel
# Processed: Train_533.jpg -> 6 bits/channel
# Processed: Train_325.jpg -> 6 bits/channel
# Processed: Train_237.jpg -> 6 bits/channel
# Processed: Train_786.jpg -> 6 bits/channel
# Processed: Train_847.jpg -> 6 bits/channel
# Processed: Train_1545.jpg -> 6 bits/channel
# Processed: Train_739.jpg -> 6 bits/channel
# Processed: Train_1267.jpg -> 6 bits/channel
# Processed: Train_155.jpg -> 6 bits/channel
# Processed: Train_670.jpg -> 6 bits/channel
# Processed: Train_510.jpg -> 6 bits/channel
# Processed: Train_1365.jpg -> 6 bits/channel
# Processed: Train_1289.jpg -> 6 bits/channel
# Processed: Train_1131.jpg -> 6 bits/channel
# Processed: Train_590.jpg -> 6 bits/channel
# Processed: Train_755.jpg -> 6 bits/channel
# Processed: Train_1559.jpg -> 6 bits/channel
# Processed: Train_169.jpg -> 6 bits/channel
# Processed: Train_1020.jpg -> 6 bits/channel
# Processed: Train_1687.jpg -> 6 bits/channel
# Processed: Train_1025.jpg -> 6 bits/channel
# Processed: Train_401.jpg -> 6 bits/channel
# Processed: Train_116.jpg -> 6 bits/channel
# Processed: Train_1171.jpg -> 6 bits/channel
# Processed: Train_882.jpg -> 6 bits/channel
# Processed: Train_1522.jpg -> 6 bits/channel
# Processed: Train_1051.jpg -> 6 bits/channel
# Processed: Train_1040.jpg -> 6 bits/channel
# Processed: Train_1503.jpg -> 6 bits/channel
# Processed: Train_876.jpg -> 6 bits/channel
# Processed: Train_255.jpg -> 6 bits/channel
# Processed: Train_716.jpg -> 6 bits/channel
# Processed: Train_1355.jpg -> 6 bits/channel
# Processed: Train_375.jpg -> 6 bits/channel
# Processed: Train_446.jpg -> 6 bits/channel
# Processed: Train_1305.jpg -> 6 bits/channel
# Processed: Train_1455.jpg -> 6 bits/channel
# Processed: Train_1359.jpg -> 6 bits/channel
# Processed: Train_1364.jpg -> 6 bits/channel
# Processed: Train_566.jpg -> 6 bits/channel
# Processed: Train_781.jpg -> 6 bits/channel
# Processed: Train_1809.jpg -> 6 bits/channel
# Processed: Train_1656.jpg -> 6 bits/channel
# Processed: Train_917.jpg -> 6 bits/channel
# Processed: Train_817.jpg -> 6 bits/channel
# Processed: Train_1507.jpg -> 6 bits/channel
# Processed: Train_562.jpg -> 6 bits/channel
# Processed: Train_1073.jpg -> 6 bits/channel
# Processed: Train_1225.jpg -> 6 bits/channel
# Processed: Train_1754.jpg -> 6 bits/channel
# Processed: Train_1810.jpg -> 6 bits/channel
# Processed: Train_666.jpg -> 6 bits/channel
# Processed: Train_665.jpg -> 6 bits/channel
# Processed: Train_890.jpg -> 6 bits/channel
# Processed: Train_194.jpg -> 6 bits/channel
# Processed: Train_773.jpg -> 6 bits/channel
# Processed: Train_340.jpg -> 6 bits/channel
# Processed: Train_1449.jpg -> 6 bits/channel
# Processed: Train_1461.jpg -> 6 bits/channel
# Processed: Train_133.jpg -> 6 bits/channel
# Processed: Train_511.jpg -> 6 bits/channel
# Processed: Train_1711.jpg -> 6 bits/channel
# Processed: Train_608.jpg -> 6 bits/channel
# Processed: Train_1797.jpg -> 6 bits/channel
# Processed: Train_1066.jpg -> 6 bits/channel
# Processed: Train_1022.jpg -> 6 bits/channel
# Processed: Train_737.jpg -> 6 bits/channel
# Processed: Train_56.jpg -> 6 bits/channel
# Processed: Train_1752.jpg -> 6 bits/channel
# Processed: Train_241.jpg -> 6 bits/channel
# Processed: Train_69.jpg -> 6 bits/channel
# Processed: Train_1124.jpg -> 6 bits/channel
# Processed: Train_875.jpg -> 6 bits/channel
# Processed: Train_912.jpg -> 6 bits/channel
# Processed: Train_1816.jpg -> 6 bits/channel
# Processed: Train_961.jpg -> 6 bits/channel
# Processed: Train_1510.jpg -> 6 bits/channel
# Processed: Train_803.jpg -> 6 bits/channel
# Processed: Train_1682.jpg -> 6 bits/channel
# Processed: Train_356.jpg -> 6 bits/channel
# Processed: Train_565.jpg -> 6 bits/channel
# Processed: Train_557.jpg -> 6 bits/channel
# Processed: Train_192.jpg -> 6 bits/channel
# Processed: Train_1548.jpg -> 6 bits/channel
# Processed: Train_397.jpg -> 6 bits/channel
# Processed: Train_681.jpg -> 6 bits/channel
# Processed: Train_1126.jpg -> 6 bits/channel
# Processed: Train_552.jpg -> 6 bits/channel
# Processed: Train_32.jpg -> 6 bits/channel
# Processed: Train_1740.jpg -> 6 bits/channel
# Processed: Train_725.jpg -> 6 bits/channel
# Processed: Train_1443.jpg -> 6 bits/channel
# Processed: Train_1470.jpg -> 6 bits/channel
# Processed: Train_923.jpg -> 6 bits/channel
# Processed: Train_896.jpg -> 6 bits/channel
# Processed: Train_707.jpg -> 6 bits/channel
# Processed: Train_1412.jpg -> 6 bits/channel
# Processed: Train_1737.jpg -> 6 bits/channel
# Processed: Train_338.jpg -> 6 bits/channel
# Processed: Train_1369.jpg -> 6 bits/channel
# Processed: Train_1695.jpg -> 6 bits/channel
# Processed: Train_1198.jpg -> 6 bits/channel
# Processed: Train_1106.jpg -> 6 bits/channel
# Processed: Train_191.jpg -> 6 bits/channel
# Processed: Train_969.jpg -> 6 bits/channel
# Processed: Train_1059.jpg -> 6 bits/channel
# Processed: Train_1706.jpg -> 6 bits/channel
# Processed: Train_205.jpg -> 6 bits/channel
# Processed: Train_1673.jpg -> 6 bits/channel
# Processed: Train_1370.jpg -> 6 bits/channel
# Processed: Train_324.jpg -> 6 bits/channel
# Processed: Train_1176.jpg -> 6 bits/channel
# Processed: Train_1568.jpg -> 6 bits/channel
# Processed: Train_916.jpg -> 6 bits/channel
# Processed: Train_223.jpg -> 6 bits/channel
# Processed: Train_14.jpg -> 6 bits/channel
# Processed: Train_80.jpg -> 6 bits/channel
# Processed: Train_179.jpg -> 6 bits/channel
# Processed: Train_482.jpg -> 6 bits/channel
# Processed: Train_543.jpg -> 6 bits/channel
# Processed: Train_104.jpg -> 6 bits/channel
# Processed: Train_1190.jpg -> 6 bits/channel
# Processed: Train_372.jpg -> 6 bits/channel
# Processed: Train_1804.jpg -> 6 bits/channel
# Processed: Train_207.jpg -> 6 bits/channel
# Processed: Train_376.jpg -> 6 bits/channel
# Processed: Train_136.jpg -> 6 bits/channel
# Processed: Train_1279.jpg -> 6 bits/channel
# Processed: Train_1288.jpg -> 6 bits/channel
# Processed: Train_1251.jpg -> 6 bits/channel
# Processed: Train_407.jpg -> 6 bits/channel
# Processed: Train_1457.jpg -> 6 bits/channel
# Processed: Train_9.jpg -> 6 bits/channel
# Processed: Train_1561.jpg -> 6 bits/channel
# Processed: Train_278.jpg -> 6 bits/channel
# Processed: Train_1803.jpg -> 6 bits/channel
# Processed: Train_1685.jpg -> 6 bits/channel
# Processed: Train_1587.jpg -> 6 bits/channel
# Processed: Train_1645.jpg -> 6 bits/channel
# Processed: Train_861.jpg -> 6 bits/channel
# Processed: Train_380.jpg -> 6 bits/channel
# Processed: Train_1140.jpg -> 6 bits/channel
# Processed: Train_633.jpg -> 6 bits/channel
# Processed: Train_348.jpg -> 6 bits/channel
# Processed: Train_17.jpg -> 6 bits/channel
# Processed: Train_423.jpg -> 6 bits/channel
# Processed: Train_428.jpg -> 6 bits/channel
# Processed: Train_1808.jpg -> 6 bits/channel
# Processed: Train_1290.jpg -> 6 bits/channel
# Processed: Train_172.jpg -> 6 bits/channel
# Processed: Train_1489.jpg -> 6 bits/channel
# Processed: Train_330.jpg -> 6 bits/channel
# Processed: Train_1074.jpg -> 6 bits/channel
# Processed: Train_576.jpg -> 6 bits/channel
# Processed: Train_740.jpg -> 6 bits/channel
# Processed: Train_243.jpg -> 6 bits/channel
# Processed: Train_571.jpg -> 6 bits/channel
# Processed: Train_1379.jpg -> 6 bits/channel
# Processed: Train_972.jpg -> 6 bits/channel
# Processed: Train_769.jpg -> 6 bits/channel
# Processed: Train_1514.jpg -> 6 bits/channel
# Processed: Train_28.jpg -> 6 bits/channel
# Processed: Train_471.jpg -> 6 bits/channel
# Processed: Train_1231.jpg -> 6 bits/channel
# Processed: Train_198.jpg -> 6 bits/channel
# Processed: Train_55.jpg -> 6 bits/channel
# Processed: Train_1075.jpg -> 6 bits/channel
# Processed: Train_83.jpg -> 6 bits/channel
# Processed: Train_931.jpg -> 6 bits/channel
# Processed: Train_1572.jpg -> 6 bits/channel
# Processed: Train_203.jpg -> 6 bits/channel
# Processed: Train_242.jpg -> 6 bits/channel
# Processed: Train_1005.jpg -> 6 bits/channel
# Processed: Train_1493.jpg -> 6 bits/channel
# Processed: Train_761.jpg -> 6 bits/channel
# Processed: Train_40.jpg -> 6 bits/channel
# Processed: Train_403.jpg -> 6 bits/channel
# Processed: Train_202.jpg -> 6 bits/channel
# Processed: Train_1786.jpg -> 6 bits/channel
# Processed: Train_865.jpg -> 6 bits/channel
# Processed: Train_877.jpg -> 6 bits/channel
# Processed: Train_913.jpg -> 6 bits/channel
# Processed: Train_687.jpg -> 6 bits/channel
# Processed: Train_379.jpg -> 6 bits/channel
# Processed: Train_490.jpg -> 6 bits/channel
# Processed: Train_534.jpg -> 6 bits/channel
# Processed: Train_395.jpg -> 6 bits/channel
# Processed: Train_1633.jpg -> 6 bits/channel
# Processed: Train_775.jpg -> 6 bits/channel
# Processed: Train_1232.jpg -> 6 bits/channel
# Processed: Train_1539.jpg -> 6 bits/channel
# Processed: Train_1234.jpg -> 6 bits/channel
# Processed: Train_15.jpg -> 6 bits/channel
# Processed: Train_76.jpg -> 6 bits/channel
# Processed: Train_344.jpg -> 6 bits/channel
# Processed: Train_387.jpg -> 6 bits/channel
# Processed: Train_1293.jpg -> 6 bits/channel
# Processed: Train_120.jpg -> 6 bits/channel
# Processed: Train_1795.jpg -> 6 bits/channel
# Processed: Train_1246.jpg -> 6 bits/channel
# Processed: Train_110.jpg -> 6 bits/channel
# Processed: Train_1007.jpg -> 6 bits/channel
# Processed: Train_1452.jpg -> 6 bits/channel
# Processed: Train_678.jpg -> 6 bits/channel
# Processed: Train_567.jpg -> 6 bits/channel
# Processed: Train_1211.jpg -> 6 bits/channel
# Processed: Train_617.jpg -> 6 bits/channel
# Processed: Train_429.jpg -> 6 bits/channel
# Processed: Train_550.jpg -> 6 bits/channel
# Processed: Train_1727.jpg -> 6 bits/channel
# Processed: Train_1436.jpg -> 6 bits/channel
# Processed: Train_405.jpg -> 6 bits/channel
# Processed: Train_384.jpg -> 6 bits/channel
# Processed: Train_1422.jpg -> 6 bits/channel
# Processed: Train_1621.jpg -> 6 bits/channel
# Processed: Train_87.jpg -> 6 bits/channel
# Processed: Train_1311.jpg -> 6 bits/channel
# Processed: Train_275.jpg -> 6 bits/channel
# Processed: Train_1321.jpg -> 6 bits/channel
# Processed: Train_478.jpg -> 6 bits/channel
# Processed: Train_1738.jpg -> 6 bits/channel
# Processed: Train_168.jpg -> 6 bits/channel
# Processed: Train_246.jpg -> 6 bits/channel
# Processed: Train_1104.jpg -> 6 bits/channel
# Processed: Train_604.jpg -> 6 bits/channel
# Processed: Train_967.jpg -> 6 bits/channel
# Processed: Train_1043.jpg -> 6 bits/channel
# Processed: Train_904.jpg -> 6 bits/channel
# Processed: Train_1016.jpg -> 6 bits/channel
# Processed: Train_1026.jpg -> 6 bits/channel
# Processed: Train_466.jpg -> 6 bits/channel
# Processed: Train_853.jpg -> 6 bits/channel
# Processed: Train_1397.jpg -> 6 bits/channel
# Processed: Train_1712.jpg -> 6 bits/channel
# Processed: Train_1710.jpg -> 6 bits/channel
# Processed: Train_1750.jpg -> 6 bits/channel
# Processed: Train_676.jpg -> 6 bits/channel
# Processed: Train_448.jpg -> 6 bits/channel
# Processed: Train_993.jpg -> 6 bits/channel
# Processed: Train_1036.jpg -> 6 bits/channel
# Processed: Train_118.jpg -> 6 bits/channel
# Processed: Train_999.jpg -> 6 bits/channel
# Processed: Train_1777.jpg -> 6 bits/channel
# Processed: Train_930.jpg -> 6 bits/channel
# Processed: Train_754.jpg -> 6 bits/channel
# Processed: Train_1622.jpg -> 6 bits/channel
# Processed: Train_529.jpg -> 6 bits/channel
# Processed: Train_1167.jpg -> 6 bits/channel
# Processed: Train_302.jpg -> 6 bits/channel
# Processed: Train_1438.jpg -> 6 bits/channel
# Processed: Train_1191.jpg -> 6 bits/channel
# Processed: Train_129.jpg -> 6 bits/channel
# Processed: Train_655.jpg -> 6 bits/channel
# Processed: Train_1299.jpg -> 6 bits/channel
# Processed: Train_514.jpg -> 6 bits/channel
# Processed: Train_459.jpg -> 6 bits/channel
# Processed: Train_299.jpg -> 6 bits/channel
# Processed: Train_834.jpg -> 6 bits/channel
# Processed: Train_808.jpg -> 6 bits/channel
# Processed: Train_1358.jpg -> 6 bits/channel
# Processed: Train_1709.jpg -> 6 bits/channel
# Processed: Train_367.jpg -> 6 bits/channel
# Processed: Train_1327.jpg -> 6 bits/channel
# Processed: Train_507.jpg -> 6 bits/channel
# Processed: Train_692.jpg -> 6 bits/channel
# Processed: Train_1789.jpg -> 6 bits/channel
# Processed: Train_793.jpg -> 6 bits/channel
# Processed: Train_411.jpg -> 6 bits/channel
# Processed: Train_1332.jpg -> 6 bits/channel
# Processed: Train_1501.jpg -> 6 bits/channel
# Processed: Train_1785.jpg -> 6 bits/channel
# Processed: Train_621.jpg -> 6 bits/channel
# Processed: Train_404.jpg -> 6 bits/channel
# Processed: Train_711.jpg -> 6 bits/channel
# Processed: Train_1357.jpg -> 6 bits/channel
# Processed: Train_444.jpg -> 6 bits/channel
# Processed: Train_1802.jpg -> 6 bits/channel
# Processed: Train_1271.jpg -> 6 bits/channel
# Processed: Train_928.jpg -> 6 bits/channel
# Processed: Train_336.jpg -> 6 bits/channel
# Processed: Train_1328.jpg -> 6 bits/channel
# ...
# Processed: Train_1463.jpg -> 6 bits/channel
# Processed: Train_1166.jpg -> 6 bits/channel
# Processed: Train_208.jpg -> 6 bits/channel
# Processed: Train_1407.jpg -> 6 bits/channel
# Processed: Train_1594.jpg -> 6 bits/channel
# Processed: Train_1013.jpg -> 6 bits/channel
# Processed: Train_1154.jpg -> 6 bits/channel
# Processed: Train_586.jpg -> 6 bits/channel
# Processed: Train_249.jpg -> 6 bits/channel
# Processed: Train_1156.jpg -> 6 bits/channel
# Processed: Train_440.jpg -> 6 bits/channel
# Processed: Train_1249.jpg -> 6 bits/channel
# Processed: Train_1347.jpg -> 6 bits/channel
# Processed: Train_1744.jpg -> 6 bits/channel
# Processed: Train_1383.jpg -> 6 bits/channel
# Processed: Train_1161.jpg -> 6 bits/channel
# Processed: Train_991.jpg -> 6 bits/channel
# Processed: Train_872.jpg -> 6 bits/channel
# Processed: Train_342.jpg -> 6 bits/channel
# Processed: Train_128.jpg -> 6 bits/channel
# Processed: Train_800.jpg -> 6 bits/channel
# Processed: Train_728.jpg -> 6 bits/channel
# Processed: Train_287.jpg -> 6 bits/channel
# Processed: Train_1184.jpg -> 6 bits/channel
# Processed: Train_1743.jpg -> 6 bits/channel
# Processed: Train_1533.jpg -> 6 bits/channel
# Processed: Train_189.jpg -> 6 bits/channel
# Processed: Train_1794.jpg -> 6 bits/channel
# Processed: Train_1268.jpg -> 6 bits/channel
# Processed: Train_1172.jpg -> 6 bits/channel
# Processed: Train_1093.jpg -> 6 bits/channel
# Processed: Train_141.jpg -> 6 bits/channel
# Processed: Train_1605.jpg -> 6 bits/channel
# Processed: Train_350.jpg -> 6 bits/channel
# Processed: Train_806.jpg -> 6 bits/channel
# Processed: Train_1818.jpg -> 6 bits/channel
# Processed: Train_1186.jpg -> 6 bits/channel
# Processed: Train_1421.jpg -> 6 bits/channel
# Processed: Train_1532.jpg -> 6 bits/channel
# Processed: Train_21.jpg -> 6 bits/channel
# Processed: Train_42.jpg -> 6 bits/channel
# Processed: Train_1203.jpg -> 6 bits/channel
# Processed: Train_849.jpg -> 6 bits/channel
# Processed: Train_409.jpg -> 6 bits/channel
# Processed: Train_360.jpg -> 6 bits/channel
# Processed: Train_1776.jpg -> 6 bits/channel
# Processed: Train_1469.jpg -> 6 bits/channel
# Processed: Train_1513.jpg -> 6 bits/channel
# Processed: Train_1188.jpg -> 6 bits/channel
# Processed: Train_1495.jpg -> 6 bits/channel
# Processed: Train_1209.jpg -> 6 bits/channel
# Processed: Train_1385.jpg -> 6 bits/channel
# Processed: Train_1105.jpg -> 6 bits/channel
# Processed: Train_1726.jpg -> 6 bits/channel
# Processed: Train_964.jpg -> 6 bits/channel
# Processed: Train_124.jpg -> 6 bits/channel
# Processed: Train_523.jpg -> 6 bits/channel
# Processed: Train_1780.jpg -> 6 bits/channel
# Processed: Train_1692.jpg -> 6 bits/channel
# Processed: Train_270.jpg -> 6 bits/channel
# Processed: Train_1570.jpg -> 6 bits/channel
# Processed: Train_1668.jpg -> 6 bits/channel
# Processed: Train_117.jpg -> 6 bits/channel
# Processed: Train_41.jpg -> 6 bits/channel
# Processed: Train_1602.jpg -> 6 bits/channel
# Processed: Train_667.jpg -> 6 bits/channel
# Processed: Train_835.jpg -> 6 bits/channel
# Processed: Train_1408.jpg -> 6 bits/channel
# Processed: Train_186.jpg -> 6 bits/channel
# Processed: Train_46.jpg -> 6 bits/channel
# Processed: Train_95.jpg -> 6 bits/channel
# Processed: Train_20.jpg -> 6 bits/channel
# Processed: Train_71.jpg -> 6 bits/channel
# Processed: Train_1480.jpg -> 6 bits/channel
# Processed: Train_1394.jpg -> 6 bits/channel
# Processed: Train_559.jpg -> 6 bits/channel
# Processed: Train_389.jpg -> 6 bits/channel
# Processed: Train_371.jpg -> 6 bits/channel
# Processed: Train_1749.jpg -> 6 bits/channel
# Processed: Train_233.jpg -> 6 bits/channel
# Processed: Train_1196.jpg -> 6 bits/channel
# Processed: Train_257.jpg -> 6 bits/channel
# Processed: Train_570.jpg -> 6 bits/channel
# Processed: Train_909.jpg -> 6 bits/channel
# Processed: Train_122.jpg -> 6 bits/channel
# Processed: Train_937.jpg -> 6 bits/channel
# Processed: Train_1296.jpg -> 6 bits/channel
# Processed: Train_1491.jpg -> 6 bits/channel
# Processed: Train_1221.jpg -> 6 bits/channel
# Processed: Train_501.jpg -> 6 bits/channel
# Processed: Train_1310.jpg -> 6 bits/channel
# Processed: Train_1497.jpg -> 6 bits/channel
# Processed: Train_1580.jpg -> 6 bits/channel
# Processed: Train_787.jpg -> 6 bits/channel
# Processed: Train_1325.jpg -> 6 bits/channel
# Processed: Train_39.jpg -> 6 bits/channel
# Processed: Train_1033.jpg -> 6 bits/channel
# Processed: Train_1731.jpg -> 6 bits/channel
# Processed: Train_226.jpg -> 6 bits/channel
# Processed: Train_551.jpg -> 6 bits/channel
# Processed: Train_1516.jpg -> 6 bits/channel
# Processed: Train_238.jpg -> 6 bits/channel
# Processed: Train_1117.jpg -> 6 bits/channel
# Processed: Train_554.jpg -> 6 bits/channel
# Processed: Train_1562.jpg -> 6 bits/channel
# Processed: Train_1782.jpg -> 6 bits/channel
# Processed: Train_62.jpg -> 6 bits/channel
# Processed: Train_1049.jpg -> 6 bits/channel
# Processed: Train_8.jpg -> 6 bits/channel
# Processed: Train_123.jpg -> 6 bits/channel
# Processed: Train_1254.jpg -> 6 bits/channel
# Processed: Train_1800.jpg -> 6 bits/channel
# Processed: Train_647.jpg -> 6 bits/channel
# Processed: Train_1170.jpg -> 6 bits/channel
# Processed: Train_935.jpg -> 6 bits/channel
# Processed: Train_119.jpg -> 6 bits/channel
# Processed: Train_44.jpg -> 6 bits/channel
# Processed: Train_929.jpg -> 6 bits/channel
# Processed: Train_30.jpg -> 6 bits/channel
# Processed: Train_1663.jpg -> 6 bits/channel
# Processed: Train_614.jpg -> 6 bits/channel
# Processed: Train_1437.jpg -> 6 bits/channel
# Processed: Train_627.jpg -> 6 bits/channel
# Processed: Train_383.jpg -> 6 bits/channel
# Processed: Train_1643.jpg -> 6 bits/channel
# Processed: Train_1164.jpg -> 6 bits/channel
# Processed: Train_346.jpg -> 6 bits/channel
# Processed: Train_1677.jpg -> 6 bits/channel
# Processed: Train_1227.jpg -> 6 bits/channel
# Processed: Train_1387.jpg -> 6 bits/channel
# Processed: Train_1465.jpg -> 6 bits/channel
# Processed: Train_1077.jpg -> 6 bits/channel
# Processed: Train_1714.jpg -> 6 bits/channel
# Processed: Train_163.jpg -> 6 bits/channel
# Processed: Train_1433.jpg -> 6 bits/channel
# Processed: Train_857.jpg -> 6 bits/channel
# Processed: Train_595.jpg -> 6 bits/channel
# Processed: Train_451.jpg -> 6 bits/channel
# Processed: Train_1629.jpg -> 6 bits/channel
# Processed: Train_1761.jpg -> 6 bits/channel
# Processed: Train_1442.jpg -> 6 bits/channel
# Processed: Train_1467.jpg -> 6 bits/channel
# Processed: Train_164.jpg -> 6 bits/channel
# Processed: Train_527.jpg -> 6 bits/channel
# Processed: Train_815.jpg -> 6 bits/channel
# Processed: Train_303.jpg -> 6 bits/channel
# Processed: Train_476.jpg -> 6 bits/channel
# Processed: Train_1566.jpg -> 6 bits/channel
# Processed: Train_34.jpg -> 6 bits/channel
# Processed: Train_1725.jpg -> 6 bits/channel
# Processed: Train_1416.jpg -> 6 bits/channel
# Processed: Train_694.jpg -> 6 bits/channel
# Processed: Train_989.jpg -> 6 bits/channel
# Processed: Train_757.jpg -> 6 bits/channel
# Processed: Train_329.jpg -> 6 bits/channel
# Processed: Train_938.jpg -> 6 bits/channel
# Processed: Train_1189.jpg -> 6 bits/channel
# Processed: Train_1214.jpg -> 6 bits/channel
# Processed: Train_215.jpg -> 6 bits/channel
# Processed: Train_1676.jpg -> 6 bits/channel
# Processed: Train_845.jpg -> 6 bits/channel
# Processed: Train_838.jpg -> 6 bits/channel
# Processed: Train_256.jpg -> 6 bits/channel
# Processed: Train_188.jpg -> 6 bits/channel
# Processed: Train_1666.jpg -> 6 bits/channel
# Processed: Train_1083.jpg -> 6 bits/channel
# Processed: Train_326.jpg -> 6 bits/channel
# Processed: Train_531.jpg -> 6 bits/channel
# Processed: Train_1204.jpg -> 6 bits/channel
# Processed: Train_496.jpg -> 6 bits/channel
# Processed: Train_957.jpg -> 6 bits/channel
# Processed: Train_1306.jpg -> 6 bits/channel
# Processed: Train_1468.jpg -> 6 bits/channel
# Processed: Train_643.jpg -> 6 bits/channel
# Processed: Train_1672.jpg -> 6 bits/channel
# Processed: Train_780.jpg -> 6 bits/channel
# Processed: Train_671.jpg -> 6 bits/channel
# Processed: Train_778.jpg -> 6 bits/channel
# Processed: Train_1603.jpg -> 6 bits/channel
# Processed: Train_1207.jpg -> 6 bits/channel
# Processed: Train_102.jpg -> 6 bits/channel
# Processed: Train_183.jpg -> 6 bits/channel
# Processed: Train_52.jpg -> 6 bits/channel
# Processed: Train_1336.jpg -> 6 bits/channel
# Processed: Train_425.jpg -> 6 bits/channel
# Processed: Train_400.jpg -> 6 bits/channel
# Processed: Train_602.jpg -> 6 bits/channel
# Processed: Train_318.jpg -> 6 bits/channel
# Processed: Train_546.jpg -> 6 bits/channel
# Processed: Train_1590.jpg -> 6 bits/channel
# Processed: Train_598.jpg -> 6 bits/channel
# Processed: Train_622.jpg -> 6 bits/channel
# Processed: Train_364.jpg -> 6 bits/channel
# Processed: Train_217.jpg -> 6 bits/channel
# Processed: Train_209.jpg -> 6 bits/channel
# Processed: Train_467.jpg -> 6 bits/channel
# Processed: Train_70.jpg -> 6 bits/channel
# Processed: Train_499.jpg -> 6 bits/channel
# Processed: Train_580.jpg -> 6 bits/channel
# Processed: Train_1747.jpg -> 6 bits/channel
# Processed: Train_1058.jpg -> 6 bits/channel
# Processed: Train_934.jpg -> 6 bits/channel
# Processed: Train_1275.jpg -> 6 bits/channel
# Processed: Train_1504.jpg -> 6 bits/channel
# Processed: Train_1287.jpg -> 6 bits/channel
# Processed: Train_922.jpg -> 6 bits/channel
# Processed: Train_484.jpg -> 6 bits/channel
# Processed: Train_953.jpg -> 6 bits/channel
# Processed: Train_1136.jpg -> 6 bits/channel
# Processed: Train_1253.jpg -> 6 bits/channel
# Processed: Train_719.jpg -> 6 bits/channel
# Processed: Train_1116.jpg -> 6 bits/channel
# Processed: Train_745.jpg -> 6 bits/channel
# Processed: Train_625.jpg -> 6 bits/channel
# Processed: Train_1518.jpg -> 6 bits/channel
# Processed: Train_944.jpg -> 6 bits/channel
# Processed: Train_1333.jpg -> 6 bits/channel
# Processed: Train_1417.jpg -> 6 bits/channel
# Processed: Train_975.jpg -> 6 bits/channel
# Processed: Train_210.jpg -> 6 bits/channel
# Processed: Train_1624.jpg -> 6 bits/channel
# Processed: Train_1174.jpg -> 6 bits/channel
# Processed: Train_645.jpg -> 6 bits/channel
# Processed: Train_184.jpg -> 6 bits/channel
# Processed: Train_1244.jpg -> 6 bits/channel
# Processed: Train_1185.jpg -> 6 bits/channel
# Processed: Train_1158.jpg -> 6 bits/channel
# Processed: Train_1142.jpg -> 6 bits/channel
# Processed: Train_414.jpg -> 6 bits/channel
# Processed: Train_839.jpg -> 6 bits/channel
# Processed: Train_1723.jpg -> 6 bits/channel
# Processed: Train_914.jpg -> 6 bits/channel
# Processed: Train_291.jpg -> 6 bits/channel
# Processed: Train_296.jpg -> 6 bits/channel
# Processed: Train_852.jpg -> 6 bits/channel
# Processed: Train_1076.jpg -> 6 bits/channel
# Processed: Train_702.jpg -> 6 bits/channel
# Processed: Train_940.jpg -> 6 bits/channel
# Processed: Train_75.jpg -> 6 bits/channel
# Processed: Train_1057.jpg -> 6 bits/channel
# Processed: Train_320.jpg -> 6 bits/channel
# Processed: Train_730.jpg -> 6 bits/channel
# Processed: Train_1647.jpg -> 6 bits/channel
# Processed: Train_568.jpg -> 6 bits/channel
# Processed: Train_132.jpg -> 6 bits/channel
# Processed: Train_19.jpg -> 6 bits/channel
# Processed: Train_91.jpg -> 6 bits/channel
# Processed: Train_810.jpg -> 6 bits/channel
# Processed: Train_1763.jpg -> 6 bits/channel
# Processed: Train_720.jpg -> 6 bits/channel
# Processed: Train_1048.jpg -> 6 bits/channel
# Processed: Train_1111.jpg -> 6 bits/channel
# Processed: Train_894.jpg -> 6 bits/channel
# Processed: Train_1652.jpg -> 6 bits/channel
# Processed: Train_50.jpg -> 6 bits/channel
# Processed: Train_932.jpg -> 6 bits/channel
# Processed: Train_382.jpg -> 6 bits/channel
# Processed: Train_152.jpg -> 6 bits/channel
# Processed: Train_1382.jpg -> 6 bits/channel
# Processed: Train_1120.jpg -> 6 bits/channel
# Processed: Train_1150.jpg -> 6 bits/channel
# Processed: Train_221.jpg -> 6 bits/channel
# Processed: Train_1137.jpg -> 6 bits/channel
# Processed: Train_985.jpg -> 6 bits/channel
# Processed: Train_1577.jpg -> 6 bits/channel
# Processed: Train_1197.jpg -> 6 bits/channel
# Processed: Train_1269.jpg -> 6 bits/channel
# Processed: Train_1460.jpg -> 6 bits/channel
# Processed: Train_390.jpg -> 6 bits/channel
# Processed: Train_1632.jpg -> 6 bits/channel
# Processed: Train_1552.jpg -> 6 bits/channel
# Processed: Train_532.jpg -> 6 bits/channel
# Processed: Train_282.jpg -> 6 bits/channel
# Processed: Train_547.jpg -> 6 bits/channel
# Processed: Train_841.jpg -> 6 bits/channel
# Processed: Train_1681.jpg -> 6 bits/channel
# Processed: Train_1598.jpg -> 6 bits/channel
# Processed: Train_1281.jpg -> 6 bits/channel
# Processed: Train_1090.jpg -> 6 bits/channel
# Processed: Train_867.jpg -> 6 bits/channel
# Processed: Train_1581.jpg -> 6 bits/channel
# Processed: Train_225.jpg -> 6 bits/channel
# Processed: Train_47.jpg -> 6 bits/channel
# Processed: Train_945.jpg -> 6 bits/channel
# Processed: Train_220.jpg -> 6 bits/channel
# Processed: Train_1128.jpg -> 6 bits/channel
# Processed: Train_1133.jpg -> 6 bits/channel
# Processed: Train_619.jpg -> 6 bits/channel
# Processed: Train_1094.jpg -> 6 bits/channel
# Processed: Train_1345.jpg -> 6 bits/channel
# Processed: Train_1675.jpg -> 6 bits/channel
# Processed: Train_1586.jpg -> 6 bits/channel
# Processed: Train_300.jpg -> 6 bits/channel
# Processed: Train_805.jpg -> 6 bits/channel
# Processed: Train_402.jpg -> 6 bits/channel
# Processed: Train_713.jpg -> 6 bits/channel
# Processed: Train_698.jpg -> 6 bits/channel
# Processed: Train_1312.jpg -> 6 bits/channel
# Processed: Train_1582.jpg -> 6 bits/channel
# Processed: Train_1466.jpg -> 6 bits/channel
# Processed: Train_828.jpg -> 6 bits/channel
# Processed: Train_756.jpg -> 6 bits/channel
# Processed: Train_487.jpg -> 6 bits/channel
# Processed: Train_174.jpg -> 6 bits/channel
# Processed: Train_1595.jpg -> 6 bits/channel
# Processed: Train_1318.jpg -> 6 bits/channel
# Processed: Train_943.jpg -> 6 bits/channel
# Processed: Train_1593.jpg -> 6 bits/channel
# Processed: Train_264.jpg -> 6 bits/channel
# Processed: Train_837.jpg -> 6 bits/channel
# Processed: Train_230.jpg -> 6 bits/channel
# Processed: Train_1334.jpg -> 6 bits/channel
# Processed: Train_284.jpg -> 6 bits/channel
# Processed: Train_266.jpg -> 6 bits/channel
# Processed: Train_381.jpg -> 6 bits/channel
# Processed: Train_1654.jpg -> 6 bits/channel
# Processed: Train_1360.jpg -> 6 bits/channel
# Processed: Train_1039.jpg -> 6 bits/channel
# Processed: Train_1543.jpg -> 6 bits/channel
# Processed: Train_272.jpg -> 6 bits/channel
# Processed: Train_553.jpg -> 6 bits/channel
# Processed: Train_1575.jpg -> 6 bits/channel
# Processed: Train_1413.jpg -> 6 bits/channel
# Processed: Train_503.jpg -> 6 bits/channel
# Processed: Train_1050.jpg -> 6 bits/channel
# Processed: Train_322.jpg -> 6 bits/channel
# Processed: Train_135.jpg -> 6 bits/channel
# Processed: Train_1014.jpg -> 6 bits/channel
# Processed: Train_941.jpg -> 6 bits/channel
# Processed: Train_1451.jpg -> 6 bits/channel
# Processed: Train_1783.jpg -> 6 bits/channel
# Processed: Train_1689.jpg -> 6 bits/channel
# Processed: Train_431.jpg -> 6 bits/channel
# Processed: Train_1505.jpg -> 6 bits/channel
# Processed: Train_1771.jpg -> 6 bits/channel
# Processed: Train_374.jpg -> 6 bits/channel
# Processed: Train_899.jpg -> 6 bits/channel
# Processed: Train_1700.jpg -> 6 bits/channel
# Processed: Train_1806.jpg -> 6 bits/channel
# Processed: Train_1079.jpg -> 6 bits/channel
# Processed: Train_295.jpg -> 6 bits/channel
# Processed: Train_269.jpg -> 6 bits/channel
# Processed: Train_415.jpg -> 6 bits/channel
# Processed: Train_1508.jpg -> 6 bits/channel
# Processed: Train_1340.jpg -> 6 bits/channel
# Processed: Train_1300.jpg -> 6 bits/channel
# Processed: Train_149.jpg -> 6 bits/channel
# Processed: Train_1608.jpg -> 6 bits/channel
# Processed: Train_97.jpg -> 6 bits/channel
# Processed: Train_744.jpg -> 6 bits/channel
# Processed: Train_1734.jpg -> 6 bits/channel
# Processed: Train_398.jpg -> 6 bits/channel
# Processed: Train_453.jpg -> 6 bits/channel
# Processed: Train_1114.jpg -> 6 bits/channel
# Processed: Train_1722.jpg -> 6 bits/channel
# Processed: Train_946.jpg -> 6 bits/channel
# Processed: Train_1473.jpg -> 6 bits/channel
# Processed: Train_333.jpg -> 6 bits/channel
# Processed: Train_1123.jpg -> 6 bits/channel
# Processed: Train_994.jpg -> 6 bits/channel
# Processed: Train_252.jpg -> 6 bits/channel
# Processed: Train_65.jpg -> 6 bits/channel
# Processed: Train_820.jpg -> 6 bits/channel
# Processed: Train_508.jpg -> 6 bits/channel
# Processed: Train_752.jpg -> 6 bits/channel
# Processed: Train_1564.jpg -> 6 bits/channel
# Processed: Train_1338.jpg -> 6 bits/channel
# Processed: Train_16.jpg -> 6 bits/channel
